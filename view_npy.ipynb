# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np_dir = r'N:\2_Analysis\automated_analysis\Useful Programs\5481---Research_Sirlin_Flint_Part_One - 4944---echo3.npy'

# %%
arr = np.load(np_dir)
arr.shape
# Out:
# (192, 192, 96)

# %%
plt.imshow(arr[:,:,45],cmap='gray')
plt.show()
